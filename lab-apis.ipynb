# %% [markdown]
# # Lab | APIs

# %% [markdown]
# In order to use the `Spotify` API (`SpotiPy`), create an account in `Spotify` and follow [these](https://developer.spotify.com/documentation/general/guides/app-settings/) steps.

# %% [markdown]
# ## Authentication and initializing the API

# %% [markdown]
# Save your client ID and your client secret in your preferred way, and read it or load it into the following variables:

# %%
CLIENT_ID = "<introduce your client id>"
CLIENT_SECRET = "<introduce your client secret>"

# %%
CLIENT_ID = "2930a873360549ed82caff396fcef906"
CLIENT_SECRET = "781f4705855f4ff99b3673c79a06e449"

# %%
# If you havent done so, install the spotipy wrapper
#!pip install spotipy

# %% [markdown]
# Once you have done it, we will start initializing the API.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=CLIENT_ID,
                                                           client_secret=CLIENT_SECRET))

# %% [markdown]
# ## Using the search method

# %% [markdown]
# Now, let's use the search method by introducing a "query". For example, let's try searching for "Lady Gaga":

# %%
results = sp.search(q='Lady Gaga', limit=50)
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=0&limit=50',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
# ...

# %%
type(results)
# Out:
# dict

# %%
results.keys() # We can see that we only have tracks
# Out:
# dict_keys(['tracks'])

# %%
results["tracks"].keys() # Let's check the values
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
results["tracks"]["href"] # Query we have searched
# Out:
# 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=0&limit=50'

# %%
results["tracks"]["items"] #items (actual tracks)
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
# ...

# %%
results["tracks"]["limit"]#Limit we have chosen
# Out:
# 50

# %%
results["tracks"]["next"] #link to the next page (next 50 tracks)
# Out:
# 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=50&limit=50'

# %%
results["tracks"]["offset"] # Actual offset (starting point)
# Out:
# 0

# %%
results["tracks"]["previous"] #Previous search

# %%
results["tracks"]["total"] # Number of matches
# Out:
# 1000

# %% [markdown]
# ## Exploring the tracks

# %%
results["tracks"]["items"][0] # Explore the first song
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
# ...

# %%
results["tracks"]["items"][0].keys() # We will focus on album, artists, id, name, popularity, type and uri
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
# Track artists
results["tracks"]["items"][0]["artists"]
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}]

# %%
# Track artists names
for artist in results["tracks"]["items"][0]["artists"]:
    print(artist["name"])
# Out:
# Lady Gaga

# %%
# Track ID
results["tracks"]["items"][0]["id"]
# Out:
# '5R8dQOPq8haW94K7mgERlO'

# %%
# Track name
results["tracks"]["items"][0]["name"]
# Out:
# 'Poker Face'

# %%
# Popularity index
results["tracks"]["items"][0]["popularity"]
# Out:
# 81

# %% [markdown]
# Spotify songs are identified by either a "url", a "uri", or an "id".
#
# - The `id` is an alphanumeric code, and it's the nuclear part of the identifier.
#
# - The `uri` contains "spotify:track" before the id. An uri is useful because it can be searched manually in the Spotify app.
#
# - The `url` is a link to the song on the Spotify web player.

# %%
results["tracks"]["items"][0]["uri"]
# Out:
# 'spotify:track:5R8dQOPq8haW94K7mgERlO'

# %% [markdown]
# ## Exercise 1: Discovering New Music through Your Favorite Artists
#
# **Objective:**
# Uncover new music by exploring the top tracks of your favorite artists and their related artists.
#
# **Instructions:**
#
# 1. **List Your Favorite Artists**:
#     - Make a list of your three favorite artists and store it in a variable named `artists`.
#     - Example: `artists = ["Los Fabulosos Cadillacs", "Manu Chao", "Muchachito Bombo Infierno"]`.
#
# 2. **Fetch Top Tracks**:
#     - Write a function named `get_top_tracks`.
#     - This function should accept an artist's name and return the name of the first 5 top tracks by that artist.
#     - Use the function `get_top_tracks` to get the first 5 top tracks for each artist in your `artists` list and store the results in a new list named `top_tracks_list`.
#
# 3. **Discover Related Artists**:
#     - Write a function named `find_related_artists`.
#     - This function should accept an artist's name and return the names of the first 5 artists related to the provided artist.
#     - Store the results in a list named `related_artists_list`.
#
# **Challenge:**
# Combine the above steps to create a playlist that includes the top tracks of your favorite artists and the top tracks of the artists related to them.

# %% [markdown]
# **Hint Section for 3. **Discover Related Artists**:**
#
# 1. **Getting Artist ID**:
#     - Remember that every artist on Spotify has a unique identifier: their `id`. To get the related artists, you first need to fetch the ID of the given artist.
#     - Consider using the `sp.search` method to query the artist's name. The method requires a `q` parameter, which is your query (in this case, the artist's name). It also has a `limit` parameter, which specifies the number of tracks it returns. In this case, 1 track is enough, since we just want the artist ID.
#     - Each track in the results has an associated 'artists' field. This field is a list containing details about all artists involved in that track.
#    - For most tracks, especially those by a single artist, this list will contain one artist. From this artist's details, you can extract the 'id' field, which is the unique identifier for that artist on Spotify.
#
#
# 3. **Fetching Related Artists**:
#     - Once you have the artist's ID, you can use another SpotiPy method to fetch related artists. Think about which SpotiPy method allows you to get related artists using an artist's ID. Here is the documentation link: https://spotipy.readthedocs.io/en/2.22.1/.
#     - This method will return a list of related artists. You'll need to extract the relevant details (artist names) from this list.
#
# 4. **Iterating for Multiple Artists**:
#     - Once you have a function that returns related artists names for one artist, you can use a list comprehension to apply this function to a list of artist names.
#
# 5. **Testing**:
#     - Always test your function with one artist name first. Once you're confident it works, then apply it to the entire list.
#
# Remember, the key is to break the problem down into manageable steps. Use the SpotiPy documentation as a resource to understand available methods and their return structures.

# %%
artist_names = ["Beyonce", "Kali Uchis", "Bad Bunny"]

def get_artist_ids(artist_names):
    artist_ids = {}
    for artist_name in artist_names:
        
        results = sp.search(q=artist_name, type='artist')
        
        if results['artists']['items']:
            artist_id = results['artists']['items'][0]['id']
            artist_ids[artist_name] = artist_id
        
    
    return artist_ids

# %%
ids = get_artist_ids(artist_names)

# %%
ids
# Out:
# {'Beyonce': '6vWDO969PvNqNYHIOW5v0m',
#  'Kali Uchis': '1U1el3k54VvEUzo3ybLPlM',
#  'Bad Bunny': '4q3ewBCX7sLwd24euuV69X'}

# %%
artist_ids = ids.values()
artist_ids
# Out:
# dict_values(['6vWDO969PvNqNYHIOW5v0m', '1U1el3k54VvEUzo3ybLPlM', '4q3ewBCX7sLwd24euuV69X'])

# %% [markdown]
# Fetch Top Tracks:
#
# Write a function named get_top_tracks.
# This function should accept an artist's name and return the name of the first 5 top tracks by that artist.
# Use the function get_top_tracks to get the first 5 top tracks for each artist in your artists list and store the results in a new list named top_tracks_list.

# %%
def get_top_tracks(ids):

    top_tracks_list = []

    for artist_name, artist_id in ids.items():
        top_tracks = sp.artist_top_tracks(artist_id, country='US')
        
        top_track_names = [track['name'] for track in top_tracks['tracks'][:5]]
        
        top_tracks_list.append((artist_name, top_track_names))
        
    return top_tracks_list

# %%
top_tracks_list = get_top_tracks(ids)

# %%
top_tracks_list
# Out:
# [('Beyonce',
#   ["TEXAS HOLD 'EM",
#    'Crazy In Love (feat. Jay-Z)',
#    'Halo',
#    'CUFF IT',
#    '16 CARRIAGES']),
#  ('Kali Uchis',
#   ['Igual Que Un Ángel (with Peso Pluma)',
#    'Moonlight',
#    'telepatía',
#    'Labios Mordidos (with KAROL G)',
#    'Melting']),
#  ('Bad Bunny',
#   ['PERRO NEGRO', 'MONACO', 'un x100to', 'Me Porto Bonito', 'WHERE SHE GOES'])]

# %%
def find_related_artists(ids):
    
    related_artists_list = []
    
    for artist_name, artist_id in ids.items():
        related_artists = sp.artist_related_artists(artist_id)
        
        related_artists_names = [artist['name'] for artist in related_artists['artists'][:5]]
        
        related_artists_list.append((artist_name, related_artists_names))
    

    return related_artists_list

# %%
find_related_artists(ids)
# Out:
# [('Beyonce',
#   ["Destiny's Child",
#    'Alicia Keys',
#    'Jennifer Lopez',
#    'Rihanna',
#    'Nicki Minaj']),
#  ('Kali Uchis',
#   ['PinkPantheress', 'Steve Lacy', 'WILLOW', 'Clairo', 'The Marías']),
#  ('Bad Bunny',
#   ['Rauw Alejandro', 'Feid', 'Anuel AA', 'Myke Towers', 'Jhayco'])]

# %%
#test

related_artists = sp.artist_related_artists('6vWDO969PvNqNYHIOW5v0m')
related_artists['artists'][9]['name']
# Out:
# 'Justin Timberlake'

# %%
# sp.user_playlist_create("2930a873360549ed82caff396fcef906", "My awesome Python playlist", public=False, collaborative=False, description="It probably won't work")

# %%
#not working

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=CLIENT_ID,
                                                           client_secret=CLIENT_SECRET))
def create_playlist(name, description='', public=False):
    # Create the playlist
    my_playlist = sp.user_playlist_create("2930a873360549ed82caff396fcef906", "My awesome Python playlist", public=False, collaborative=False, description="It probably won't work")
    return my_playlist

# %%
from spotipy.oauth2 import SpotifyOAuth

# Initialize Spotipy with user authorization
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=CLIENT_ID,
                                                client_secret=CLIENT_SECRET,
                                                redirect_uri="http://localhost:8080",
                                                scope="playlist-modify-public"))

def create_playlist(name, description='', public=True):
    # Create the playlist
    my_playlist = sp.user_playlist_create(sp.me()['id'], name, public=public, collaborative=False, description=description)
    return my_playlist

# %%
my_playlist = create_playlist("My awesome Python playlist", description="It probably won't work")
print(my_playlist)
# Out:
# {'collaborative': False, 'description': "It probably won't work", 'external_urls': {'spotify': 'https://open.spotify.com/playlist/3jcZqhcH8rgA5FYScWdarc'}, 'followers': {'href': None, 'total': 0}, 'href': 'https://api.spotify.com/v1/playlists/3jcZqhcH8rgA5FYScWdarc', 'id': '3jcZqhcH8rgA5FYScWdarc', 'images': [], 'name': 'My awesome Python playlist', 'owner': {'display_name': '11162383676', 'external_urls': {'spotify': 'https://open.spotify.com/user/11162383676'}, 'href': 'https://api.spotify.com/v1/users/11162383676', 'id': '11162383676', 'type': 'user', 'uri': 'spotify:user:11162383676'}, 'primary_color': None, 'public': True, 'snapshot_id': 'MSwwZWUxYWM3NGYwMDQxMTM3NTY2NDBlYjZiODdiYzZiZTM0MDQ0MjEz', 'tracks': {'href': 'https://api.spotify.com/v1/playlists/3jcZqhcH8rgA5FYScWdarc/tracks', 'items': [], 'limit': 100, 'next': None, 'offset': 0, 'previous': None, 'total': 0}, 'type': 'playlist', 'uri': 'spotify:playlist:3jcZqhcH8rgA5FYScWdarc'}

# %%
print("Playlist Name:", my_playlist['name'])
print("Playlist ID:", my_playlist['id'])
print("Playlist description:", my_playlist['description'])
print("Playlist owner id:", my_playlist['owner']['id'])
# Out:
# Playlist Name: My awesome Python playlist
# Playlist ID: 3jcZqhcH8rgA5FYScWdarc
# Playlist description: It probably won't work
# Playlist owner id: 11162383676

# %%
# no creo que esto haya funcionado

def follow_playlist(my_playlist_owner_id, my_playlist_id):
    sp.user_playlist_follow_playlist(my_playlist_owner_id, my_playlist_id)

# Replace the placeholders with your actual IDs
my_playlist_owner_id = '11162383676'
my_playlist_id = '3jcZqhcH8rgA5FYScWdarc'

# Call the function with your actual IDs
follow_playlist(my_playlist_owner_id, my_playlist_id)

# %%
def get_top_tracks(ids):

    top_tracks_list = []

    for artist_name, artist_id in ids.items():
        top_tracks = sp.artist_top_tracks(artist_id, country='US')
        
        top_track_names = [track['name'] for track in top_tracks['tracks'][:5]]
        
        top_tracks_list.append((artist_name, top_track_names))
        
    return top_tracks_list

# %%
related_artist_names = list(related_artists)

related_artist_names
# Out:
# [('Beyonce',
#   ["Destiny's Child",
#    'Alicia Keys',
#    'Jennifer Lopez',
#    'Rihanna',
#    'Nicki Minaj']),
#  ('Kali Uchis',
#   ['PinkPantheress', 'Steve Lacy', 'WILLOW', 'Clairo', 'The Marías']),
#  ('Bad Bunny',
#   ['Rauw Alejandro', 'Feid', 'Anuel AA', 'Myke Towers', 'Jhayco'])]

# %%
def get_related_artist_ids(related_artist_names):
    related_artist_ids = {}
    for artist_name, related_artist_list in related_artist_names:
        for related_artist_name in related_artist_list:
        
            results = sp.search(q=related_artist_name, type='artist')
        
            if results['artists']['items']:
                related_artist_id = results['artists']['items'][0]['id']
                related_artist_ids[related_artist_name] = related_artist_id
        
    
    return related_artist_ids


ids2 = get_related_artist_ids(related_artist_names)
ids2
# Out:
# {"Destiny's Child": '1Y8cdNmUJH7yBTd9yOvr5i',
#  'Alicia Keys': '3DiDSECUqqY1AuBP8qtaIa',
#  'Jennifer Lopez': '2DlGxzQSjYe5N6G9nkYghR',
#  'Rihanna': '5pKCCKE2ajJHZ9KAiaK11H',
#  'Nicki Minaj': '0hCNtLu0JehylgoiP8L4Gh',
#  'PinkPantheress': '78rUTD7y6Cy67W1RVzYs7t',
#  'Steve Lacy': '57vWImR43h4CaDao012Ofp',
#  'WILLOW': '3rWZHrfrsPBxVy692yAIxF',
#  'Clairo': '3l0CmX0FuQjFxr8SK7Vqag',
#  'The Marías': '2sSGPbdZJkaSE2AbcGOACx',
#  'Rauw Alejandro': '1mcTU81TzQhprhouKaTkpq',
#  'Feid': '2LRoIwlKmHjgvigdNGBHNo',
#  'Anuel AA': '2R21vXR83lH98kGeO99Y66',
#  'Myke Towers': '7iK8PXO48WeuP03g8YR51W',
#  'Jhayco': '6nVcHLIgY5pE2YCl8ubca1'}

# %%
ids.update(ids2)
ids
# Out:
# {'Beyonce': '6vWDO969PvNqNYHIOW5v0m',
#  'Kali Uchis': '1U1el3k54VvEUzo3ybLPlM',
#  'Bad Bunny': '4q3ewBCX7sLwd24euuV69X',
#  "Destiny's Child": '1Y8cdNmUJH7yBTd9yOvr5i',
#  'Alicia Keys': '3DiDSECUqqY1AuBP8qtaIa',
#  'Jennifer Lopez': '2DlGxzQSjYe5N6G9nkYghR',
#  'Rihanna': '5pKCCKE2ajJHZ9KAiaK11H',
#  'Nicki Minaj': '0hCNtLu0JehylgoiP8L4Gh',
#  'PinkPantheress': '78rUTD7y6Cy67W1RVzYs7t',
#  'Steve Lacy': '57vWImR43h4CaDao012Ofp',
#  'WILLOW': '3rWZHrfrsPBxVy692yAIxF',
#  'Clairo': '3l0CmX0FuQjFxr8SK7Vqag',
#  'The Marías': '2sSGPbdZJkaSE2AbcGOACx',
#  'Rauw Alejandro': '1mcTU81TzQhprhouKaTkpq',
#  'Feid': '2LRoIwlKmHjgvigdNGBHNo',
#  'Anuel AA': '2R21vXR83lH98kGeO99Y66',
#  'Myke Towers': '7iK8PXO48WeuP03g8YR51W',
#  'Jhayco': '6nVcHLIgY5pE2YCl8ubca1'}

# %%
top_tracks_list = get_top_tracks(ids)
top_tracks_list
# Out:
# [('Beyonce',
#   ["TEXAS HOLD 'EM",
#    'Crazy In Love (feat. Jay-Z)',
#    'Halo',
#    'CUFF IT',
#    '16 CARRIAGES']),
#  ('Kali Uchis',
#   ['Igual Que Un Ángel (with Peso Pluma)',
#    'Moonlight',
#    'telepatía',
#    'Labios Mordidos (with KAROL G)',
#    'Melting']),
#  ('Bad Bunny',
#   ['PERRO NEGRO', 'MONACO', 'un x100to', 'Me Porto Bonito', 'WHERE SHE GOES']),
#  ("Destiny's Child",
#   ['Say My Name',
#    'Survivor',
#    "Jumpin', Jumpin'",
#    'Bills, Bills, Bills',
#    'Independent Women, Pt. 1 - Pasadena Remix']),
#  ('Alicia Keys',
#   ["If I Ain't Got You", 'My Boo', 'No One', 'Girl on Fire', "Fallin'"]),
#  ('Jennifer Lopez',
#   ['On The Floor',
#    "Let's Get Loud",
#    'Jenny from the Block (feat. Jadakiss & Styles P.) - Track Masters Remix',
#    'On The Floor - Radio Edit',
#    'El Ultimo Adiós - Varios Artistas Version']),
#  ('Rihanna',
#   ['We Found Love',
#    'Umbrella',
#    'Only Girl (In The World)',
#    'Love On The Brain',
# ...

# %%
def get_tracks_uris(top_tracks_list):
    track_uris = []
    for artist_name, tracks in top_tracks_list:
        for track_name in tracks:
        
            results = sp.search(q=track_name, type='track', limit=1)
        
            if results['tracks']['items']:
                track_uri = results['tracks']['items'][0]['uri']
                track_uris.append(track_uri)
    return track_uris

# %%
uris_list = get_tracks_uris(top_tracks_list)

# %%
uris_list
# Out:
# ['spotify:track:0Z7nGFVCLfixWctgePsRk9',
#  'spotify:track:0TwBtDAWpkpM3srywFVOV5',
#  'spotify:track:4JehYebiI9JE8sR8MisGVb',
#  'spotify:track:1xzi1Jcr7mEi9K2RfzLOqS',
#  'spotify:track:3Fwebmu4BzPUpDtPZo0qHb',
#  'spotify:track:6XaJfhwof7qIgbbXO5tIQI',
#  'spotify:track:2i2gDpKKWjvnRTOZRhaPh2',
#  'spotify:track:6tDDoYIxWvMLTdKpjFkc1B',
#  'spotify:track:5ycn8M0WNGedabDuaH9mQT',
#  'spotify:track:2kSb3wYSOV996xA2NSmpck',
#  'spotify:track:7iQXYTyuG13aoeHxGG28Nh',
#  'spotify:track:4MjDJD8cW7iVeWInc2Bdyj',
#  'spotify:track:6pD0ufEQq0xdHSsRbg9LBK',
#  'spotify:track:6Sq7ltF9Qa7SNFBsV5Cogx',
#  'spotify:track:7ro0hRteUMfnOioTFI5TG1',
#  'spotify:track:0YammaEkYSeo9vQYZ1OwS6',
#  'spotify:track:2Mpj1Ul5OFPyyP4wB62Rvi',
#  'spotify:track:4pmc2AxSEq6g7hPVlJCPyP',
#  'spotify:track:1Oi2zpmL81Q0yScF1zxaC0',
#  'spotify:track:5JZpQuRIX8MTiKwuELjTlx',
#  'spotify:track:3XVBdLihbNbxUwZosxcGuJ',
#  'spotify:track:68vgtRHr7iZHpzGpon6Jlo',
#  'spotify:track:6IwKcFdiRQZOWeYNhUiWIv',
# ...

# %%
def add_tracks(user_id, playlist_id, uris_list, position=None):

    sp.user_playlist_add_tracks(user_id, playlist_id, uris_list, position=position)

    
user_id = '11162383676'
playlist_id = '3jcZqhcH8rgA5FYScWdarc'
    

# Call the add_tracks function
add_tracks(user_id, playlist_id, uris_list)

# %% [markdown]
# ## Playlists
#
# The `sp.featured_playlists()` method in `spotipy` fetches a list of Spotify's featured playlists at a given moment. These are curated playlists that Spotify often highlights on the platform's homepage. The method provides a snapshot of the playlists that are being promoted or featured by Spotify at the time of the request.
#
# Once you've fetched the featured playlists, you can extract their IDs (and other details).

# %%
sp.featured_playlists() # We get a playlist id of a playlist we like
# Out:
# {'message': 'Popular Playlists',
#  'playlists': {'href': 'https://api.spotify.com/v1/browse/featured-playlists?offset=0&limit=20',
#   'items': [{'collaborative': False,
#     'description': 'Parangolé, Leo Santana e os maiores hits do país. O que tá bombando tá aqui.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX0FOF1IUWK1W'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0FOF1IUWK1W',
#     'id': '37i9dQZF1DX0FOF1IUWK1W',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000297af2a2e0f6e7eaa902dc284',
#       'width': None}],
#     'name': 'Top Brasil',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#FFFFFF',
#     'public': True,
# ...

# %% [markdown]
# ### Getting a Playlist's Details
# To fetch details about a specific playlist, you can use the playlist method. You'll need the playlist's Spotify ID.

# %% [markdown]
# In this example, we will use the following playlist id: *37i9dQZF1DXd9zR7tdziuQ*

# %%
playlist_id = "37i9dQZF1DXd9zR7tdziuQ"
playlist = sp.playlist(playlist_id)

# %%
print(playlist['name'])  # Print the playlist's name
print(playlist['description'])  # Print the playlist's description
# Out:
# Hits acústicos
# Relájate con tus canciones favoritas en versión acústica / Descontrai com versões acústicas das tuas músicas preferidas.

# %% [markdown]
# ### Getting Tracks from a Playlist
# If you want to get the tracks from a specific playlist, you can use the playlist_tracks method.

# %%
tracks = sp.playlist_tracks(playlist_id)
for track in tracks['items']:
    print(track['track']['name'])  # Print each track's name
# Out:
# Take Me Home, Country Roads
# Cold Heart - Acoustic
# If I Ain't Got You - Piano & Vocal Version
# Wicked Game - Recorded Live at St Canice Cathedral, Kilkenny
# Time After Time
# I'm Not the Only One - Live from Spotify, London
# Blinding Lights
# Let Her Go (Acoustic Version)
# Stay With Me - Live From Spotify Berlin
# No One - Acoustic
# Can't Help Falling in Love
# Bizarre Love Triangle - 2014 Remaster
# La Vie En Rose
# Wake Me Up - Acoustic
# IDGAF - Acoustic
# Fix You - Live
# Perfect - Acoustic
# Stand By Me
# Sunday Morning - Acoustic
# Another Love - Live from Spotify (SXSW)
# Wild Love - Acoustic
# Billie Jean
# City of Stars
# Dreams - Piano Version
# Too Good At Goodbyes - Acoustic
# Baby One More Time - Recorded at Spotify Studios New York City
# Collide - Acoustic Version
# September Song - Guitar Acoustic
# Fast Car
# Days Like This
# True Colours
# Shape of You - Acoustic
# Naked - Acoustic Version
# Unchained Melody
# Better Together
# ...

# %% [markdown]
# ### Getting Artists from a Playlist
#
# To extract all the artists from the tracks in a playlist, you'd typically follow these steps:
#
# 1. Fetch the playlist's tracks.
# 2. Iterate through each track.
# 3. For each track, extract the associated artists.

# %%
# List to store unique artist names
artists_list = []

for track_item in tracks['items']:
    track = track_item['track']
    for artist in track['artists']:
        artist_name = artist['name']
        if artist_name not in artists_list:  # This ensures each artist is added only once
            artists_list.append(artist_name)

print(artists_list)
# Out:
# ['Lana Del Rey', 'Elton John', 'Dua Lipa', 'Alicia Keys', 'James Vincent McMorrow', 'Iron & Wine', 'Ouvindo', 'Passenger', 'Angus & Julia Stone', 'Kacey Musgraves', 'Frente!', 'Daniela Andrade', 'Aloe Blacc', 'Sam Smith', 'Ed Sheeran', 'Florence + The Machine', 'Maroon 5', 'Tom Odell', 'James Bay', 'The Civil Wars', 'Gavin James', 'Lissie', 'Howie Day', 'JP Cooper', 'Black Pumas', 'Dermot Kennedy', 'James Arthur', 'Lykke Li', 'Us The Duo', 'Jasmine Thompson', 'John Legend', 'Kygo', 'Conrad Sewell', 'Jessie J', 'Arlo Parks', 'The Lumineers', 'Charlie Puth', 'The Wind and The Wave', 'The Mayries', 'Missy & Blonde', 'Julia Ross', 'Sixpence None The Richer', 'Halloran & Kate', 'Sia', 'Lauv', 'Joy Williams', 'Julia Michaels', 'Julia Sheer', 'Jon D', 'Taken By Trees', 'Calum Scott', 'Aaron Krause', 'Liza Anne', 'Eddie Berman', 'James TW', 'Lotte Kestner', 'Francesco Yates', "Israel Kamakawiwo'ole", 'Sarah Jarosz', 'Lily Allen', 'John Mayer', 'Matt Johnson', 'Niall Horan', 'James Blunt', 'N
# ...

# %% [markdown]
# ## Exercise 2: Unraveling the World of Playlists
#
#
# 1. **Featured Exploration**:
#    - Fetch the list of Spotify's current featured playlists.
#    - Extract and display the names and IDs of the top 5 featured playlists.
#
# 2. **Deep Dive**:
#    - Choose any one of the top 5 featured playlists (you can choose the one you personally find most interesting or simply pick one randomly).
#    - Fetch and display its name, description, and total track count.
#
# 3. **Track-tastic**:
#    - Extract and display the names of the first 10 tracks in the chosen playlist.
#
# 4. **Artistic Flair**:
#    - Create a dictionary where the keys are the names of the first 10 tracks, and the values are lists containing the names of the artists associated with each track.
#    - For example: `{"TrackName1": ["Artist1", "Artist2"], "TrackName2": ["Artist3"]}`

# %% [markdown]
# Getting a Playlist's Details
# To fetch details about a specific playlist, you can use the playlist method. You'll need the playlist's Spotify ID.
#
# playlist_id = "37i9dQZF1DXd9zR7tdziuQ"
# playlist = sp.playlist(playlist_id)
#
# print(playlist['name'])  # Print the playlist's name
# print(playlist['description'])  # Print the playlist's description

# %%
featured_playlists = sp.featured_playlists()
featured_playlists
# Out:
# {'message': 'Popular Playlists',
#  'playlists': {'href': 'https://api.spotify.com/v1/browse/featured-playlists?offset=0&limit=20',
#   'items': [{'collaborative': False,
#     'description': 'Parangolé, Leo Santana e os maiores hits do país. O que tá bombando tá aqui.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX0FOF1IUWK1W'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0FOF1IUWK1W',
#     'id': '37i9dQZF1DX0FOF1IUWK1W',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000297af2a2e0f6e7eaa902dc284',
#       'width': None}],
#     'name': 'Top Brasil',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#FFFFFF',
#     'public': True,
# ...

# %%
featured_playlists.keys()
# Out:
# dict_keys(['message', 'playlists'])

# %%
featured_playlists["playlists"].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
featured_playlists["playlists"]["items"][0]["id"]
# Out:
# '37i9dQZF1DX0FOF1IUWK1W'

# %%
featured_playlists["playlists"]["items"][0]["name"]
# Out:
# 'Top Brasil'

# %%
top_featured_playlists = {}
for playlist in featured_playlists["playlists"]["items"][:5]:
    playlist_id = playlist["id"]
    playlist_name = playlist["name"]
    top_featured_playlists[playlist_name] = [playlist_id]
 
print(top_featured_playlists)
# Out:
# {'Top Brasil': ['37i9dQZF1DX0FOF1IUWK1W'], 'Funk Hits': ['37i9dQZF1DWTkIwO2HDifB'], 'Esquenta Sertanejo': ['37i9dQZF1DXdSjVZQzv2tl'], 'Pagodeira': ['37i9dQZF1DWVjNkaVEkL3X'], 'Paredão Explode': ['37i9dQZF1DXcedEPj5nsZ0']}

# %%
# na solucion_lab_5 tem o codigo pra fazer bucle

# %% [markdown]
# Deep Dive:
#
# Choose any one of the top 5 featured playlists.
# Fetch and display its name, description, and total track count.

# %%
playlist_id = "37i9dQZF1DX0FOF1IUWK1W"
playlist = sp.playlist(playlist_id)

print(playlist['name'])  # Print the playlist's name
print(playlist['description'])  # Print the playlist's description
# Out:
# Top Brasil
# Parangolé, Leo Santana e os maiores hits do país. O que tá bombando tá aqui.

# %%
sp.playlist(playlist_id)
# Out:
# {'collaborative': False,
#  'description': 'Parangolé, Leo Santana e os maiores hits do país. O que tá bombando tá aqui.',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX0FOF1IUWK1W'},
#  'followers': {'href': None, 'total': 8168349},
#  'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0FOF1IUWK1W?additional_types=track',
#  'id': '37i9dQZF1DX0FOF1IUWK1W',
#  'images': [{'height': None,
#    'url': 'https://i.scdn.co/image/ab67706f0000000297af2a2e0f6e7eaa902dc284',
#    'width': None}],
#  'name': 'Top Brasil',
#  'owner': {'display_name': 'Spotify',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#   'href': 'https://api.spotify.com/v1/users/spotify',
#   'id': 'spotify',
#   'type': 'user',
#   'uri': 'spotify:user:spotify'},
#  'primary_color': '#FFFFFF',
#  'public': True,
#  'snapshot_id': 'MTcwODAwOTIwMCwwMDAwMDAwMDE2MWM4ODZiM2ZmYTUzOTk1MjVhZjZkN2JmMWU0ZmJl',
# ...

# %%
def get_playlist_track_count(playlist_id):
    playlist_details = sp.playlist(playlist_id)
    track_count = playlist_details['tracks']['total']
    return track_count

# %%
print(get_playlist_track_count(playlist_id))
# Out:
# 50

# %% [markdown]
# Track-tastic:
#
# Extract and display the names of the first 10 tracks in the chosen playlist.

# %%
sp.playlist(playlist_id)['tracks']

# %%
for item in sp.playlist(playlist_id)['tracks']['items'][:10]:
    track_name = item['track']['name']
    print(track_name)
# Out:
# Perna Bamba
# Macetando
# Dia de Fluxo
# Baby Eu Tava na Rua da Água
# Cama Repetida
# POCPOC
# Me Leva Pra Casa / Escrito Nas Estrelas / Saudade - Ao Vivo
# DANÇA PRA ME PROVOCAR
# Tipo Hollywood
# 30 Cadeados - Ao Vivo

# %%
names = [e['track']['name'] for e in sp.playlist(playlist_id)['tracks']['items'][:10]]

# %%
names
# Out:
# ['Perna Bamba',
#  'Macetando',
#  'Dia de Fluxo',
#  'Baby Eu Tava na Rua da Água',
#  'Cama Repetida',
#  'POCPOC',
#  'Me Leva Pra Casa / Escrito Nas Estrelas / Saudade - Ao Vivo',
#  'DANÇA PRA ME PROVOCAR',
#  'Tipo Hollywood',
#  '30 Cadeados - Ao Vivo']

# %% [markdown]
# Artistic Flair:
#
# Create a dictionary where the keys are the names of the first 10 tracks, and the values are lists containing the names of the artists associated with each track.
# For example: {"TrackName1": ["Artist1", "Artist2"], "TrackName2": ["Artist3"]}

# %%
dictio = {}

tracks = sp.playlist(playlist_id)['tracks']['items'][:10]

for track in tracks:
    track_name = track['track']['name']
    
    artists = [artist['name'] for artist in track['track']['artists']]
    
    dictio[track_name] = artists

print(dictio)
# Out:
# {'Perna Bamba': ['Parangolé', 'Leo Santana'], 'Macetando': ['Ivete Sangalo', 'LUDMILLA'], 'Dia de Fluxo': ['AgroPlay', 'Ana Castela', 'LUDMILLA'], 'Baby Eu Tava na Rua da Água': ['TR', 'Mc Menor RV', 'Tropa da W&S'], 'Cama Repetida': ['Leo Santana', 'Zé Felipe'], 'POCPOC': ['PEDRO SAMPAIO'], 'Me Leva Pra Casa / Escrito Nas Estrelas / Saudade - Ao Vivo': ['Lauana Prado'], 'DANÇA PRA ME PROVOCAR': ['DJ JOÃO PEREIRA', 'MC Koringa'], 'Tipo Hollywood': ['Mc Ws da leste', 'MC Cothiê', 'Dj Chadin do C'], '30 Cadeados - Ao Vivo': ['Gusttavo Lima', 'Mari Fernandez']}
